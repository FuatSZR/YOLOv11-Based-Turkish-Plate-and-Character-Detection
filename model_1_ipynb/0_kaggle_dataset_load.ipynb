# %%
# %cd /content/drive/MyDrive/Plate_Recognition
# Out:
# /content/drive/MyDrive/yolo_v8/Plate_Recognizing/plate_recg/recog_new

# %%
# !mkdir -p ~/.kaggle

# %%
# !mv kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
import os
from google.colab import drive
import kagglehub

# %%
os.environ['KAGGLE_USERNAME'] = '...'
os.environ['KAGGLE_KEY'] = '...'

print("Ortam değişkenleri ayarlandı. İndirme tekrar denenecek.")
# Out:
# Ortam değişkenleri ayarlandı. İndirme tekrar denenecek.

# %%
# Download latest version
path = kagglehub.dataset_download("smaildurcan/turkish-license-plate-dataset")

print("Path to dataset files:", path)

# %%
import shutil
import os

# Kaggle
SOURCE_PATH = "/kaggle/input/turkish-license-plate-dataset"

# Hedef yol
TARGET_PATH = "/content/drive/MyDrive/Plate_Recognition/data"

print(f"'{SOURCE_PATH}' adresindeki veri seti '{TARGET_PATH}' adresine kopyalanıyor...")

# Kopyalama
if os.path.exists(TARGET_PATH):
    shutil.rmtree(TARGET_PATH)

shutil.copytree(SOURCE_PATH, TARGET_PATH)

print("✅ Kopyalama tamamlandı. Artık düzenlenebilir!")


IMAGES_DIR = os.path.join(TARGET_PATH, 'images')
# Out:
# '/kaggle/input/turkish-license-plate-dataset' adresindeki veri seti '/content/drive/MyDrive/Plate_Recognition/data' adresine kopyalanıyor...
# ✅ Kopyalama tamamlandı. Artık düzenlenebilir!
