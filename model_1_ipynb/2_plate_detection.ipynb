# %%
# %cd /content/drive/MyDrive/Plate_Recognition
# Out:
# /content/drive/MyDrive/Plate_Recognition

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.3/112.6 GB disk)

# %%
import cv2
from google.colab.patches import cv2_imshow
import imutils
import numpy as np
from ultralytics import YOLO

# %%
# !yolo detect train data=turkish_plate_data_splitted/config.yaml model=yolo11n.pt   epochs=50 patience= 10  imgsz=640 workers = 8 batch=16 device=0 name=plate_det-yolov11n
# Out:
# ...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict model=runs/detect/plate_det-yolov11n/weights/best.pt source=turkish_plate_data_splitted/test/images
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/196 /content/drive/MyDrive/Plate_Recognition/turkish_plate_data_splitted/test/images/1004.jpg: 640x640 1 plate, 8.7ms
# image 2/196 /content/drive/MyDrive/Plate_Recognition/turkish_plate_data_splitted/test/images/1016.jpg: 480x640 1 plate, 427.3ms
# image 3/196 /content/drive/MyDrive/Plate_Recognition/turkish_plate_data_splitted/test/images/1020.jpg: 480x640 1 plate, 8.6ms
# image 4/196 /content/drive/MyDrive/Plate_Recognition/turkish_plate_data_splitted/test/images/1036.jpg: 640x480 1 plate, 49.9ms
# image 5/196 /content/drive/MyDrive/Plate_Recognition/turkish_plate_data_splitted/test/images/1038.jpg: 640x480 1 plate, 8.5ms
# image 6/196 /content/drive/MyDrive/Plate_Recognition/turkish_plate_data_splitted/test/images/1047.jpg: 384x640 1 plate, 49.8ms
# ...
